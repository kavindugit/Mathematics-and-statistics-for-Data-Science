# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\HP\Maths and statistics course codebasics\files\chapter6_assets\4_detect_outliers_using_normal_distribution\heights_with_outliers.csv")
df
# Out:
#          name  height
# 0       Aarav    5.45
# 1     Deepika    8.20
# 2    Abhishek    5.65
# 3       Sneha    5.52
# 4       Kriti    5.69
# ..        ...     ...
# 995     Susan    5.51
# 996     Sarah    5.85
# 997     Susan    6.12
# 998   Michael    5.81
# 999     David    5.41
#
# [1000 rows x 2 columns]

# %%
mean = df.height.mean()
std = df.height.std()

mean , std
# Out:
# (5.61118, 0.3726535633511086)

# %%
sns.histplot(df.height , kde = True)

plt.axvline(mean , color = "k" , linestyle = 'dashed' , linewidth = 1)

plt.axvline(mean + std , color = "r" , linestyle ='dashed' , linewidth = 1)
plt.axvline(mean - std , color = "r" , linestyle ='dashed' , linewidth = 1)

plt.axvline(mean + std * 2 , color = "r" , linestyle ='dashed' , linewidth = 1)
plt.axvline(mean - std * 2 , color = "r" , linestyle ='dashed' , linewidth = 1)

plt.axvline(mean + std * 3 , color = "g" , linestyle ='dashed' , linewidth = 1)
plt.axvline(mean - std * 3 , color = "g" , linestyle ='dashed' , linewidth = 1)

# %%
df['Z_score'] = (df['height'] - mean) / std
df.head()
# Out:
#        name  height   Z_score
# 0     Aarav    5.45 -0.432520
# 1   Deepika    8.20  6.946988
# 2  Abhishek    5.65  0.104172
# 3     Sneha    5.52 -0.244678
# 4     Kriti    5.69  0.211510

# %%
df[(df.Z_score < -3) | (df.Z_score > 3)]
# Out:
#        name  height    Z_score
# 1   Deepika     8.2   6.946988
# 16    Tanvi     3.2  -6.470299
# 57    Priya     3.4  -5.933608
# 76    Aarav     9.4  10.167137

# %%
df_no_outliers = df[(df.Z_score > -3) & (df.Z_score < 3)] 
df_no_outliers
# Out:
#          name  height   Z_score
# 0       Aarav    5.45 -0.432520
# 2    Abhishek    5.65  0.104172
# 3       Sneha    5.52 -0.244678
# 4       Kriti    5.69  0.211510
# 5       Sneha    5.24 -0.996046
# ..        ...     ...       ...
# 995     Susan    5.51 -0.271512
# 996     Sarah    5.85  0.640863
# 997     Susan    6.12  1.365397
# 998   Michael    5.81  0.533525
# 999     David    5.41 -0.539858
#
# [996 rows x 3 columns]

# %%
sns.histplot(df_no_outliers.height , kde = True)

plt.axvline(mean , color = "k" , linestyle = 'dashed' , linewidth = 1)

plt.axvline(mean + std , color = "r" , linestyle ='dashed' , linewidth = 1)
plt.axvline(mean - std , color = "r" , linestyle ='dashed' , linewidth = 1)

plt.axvline(mean + std * 2 , color = "r" , linestyle ='dashed' , linewidth = 1)
plt.axvline(mean - std * 2 , color = "r" , linestyle ='dashed' , linewidth = 1)

plt.axvline(mean + std * 3 , color = "g" , linestyle ='dashed' , linewidth = 1)
plt.axvline(mean - std * 3 , color = "g" , linestyle ='dashed' , linewidth = 1)

# %%
np.random.seed(42)  # For reproducibility

# Generating experience data
experience_years = ([10,11,13,14,14,16,17,18,18,12,10,11,15,16,12,5,4,3,2,3])

# Creating DataFrame
dff = pd.DataFrame({
    'Developer_ID': range(1, 21),
    'Years_of_Experience': experience_years
})

# %%
sns.histplot(dff['Years_of_Experience'],kde=True)
# Out:
# <Axes: xlabel='Years_of_Experience', ylabel='Count'>
