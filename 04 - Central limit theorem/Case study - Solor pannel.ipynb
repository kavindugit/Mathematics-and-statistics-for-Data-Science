# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\HP\Maths and statistics course codebasics\files\chapter9_assets\4_clt_solar_panels_coding\bill_survey.csv");
df.head()
# Out:
#      City   Bill
# 0  Mumbai  15400
# 1  Mumbai   6700
# 2  Mumbai  16300
# 3  Mumbai   2100
# 4  Mumbai   4600

# %%
df.City.nunique()
# Out:
# 207

# %%
sns.histplot(df.Bill , kde = True)

#all data ploting
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
df[df.City == "Mumbai"].Bill
# Out:
# 0     15400
# 1      6700
# 2     16300
# 3      2100
# 4      4600
# 5      6800
# 6      8600
# 7      5500
# 8      6900
# 9      6400
# 10    13300
# 11     4200
# 12      200
# 13     8000
# 14    19900
# 15     1200
# 16    13600
# 17    13100
# 18     2300
# 19      600
# 20    11400
# 21    11300
# 22     1900
# 23     1300
# 24     3300
# 25     3500
# 26     1000
# 27     4200
# 28     2300
# 29     6700
# 30     4900
# 31     6800
# 32     2900
# 33     3700
# 34     2500
# 35      900
# 36     1000
# 37     7000
# 38     8400
# 39     5500
# 40     6700
# 41     2800
# 42     3900
# 43     5200
# 44     1700
# 45     9400
# 46     7000
# 47     1100
# 48    11100
# 49     4300
# Name: Bill, dtype: int64

# %%
# Mumbai City data ploting

sns.histplot( df[df.City == "Mumbai"].Bill, kde = True)
# Out:
# <Axes: xlabel='Bill', ylabel='Count'>

# %%
sample_means =[]
for city , subdf in df.groupby("City"):
    sample_means.append(subdf.Bill.mean())

len(sample_means)
# Out:
# 207

# %%
sns.histplot(sample_means , kde = True)
# Out:
# <Axes: ylabel='Count'>
